# %% [markdown]
# <a href="https://colab.research.google.com/github/mackrasz/cyfrowe_przetwarzanie_obrazow/blob/master/Zadanie_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dekonwolucja**

# %% [markdown]
# To zadanie polega na wykorzystaniu dekonwolucji do poprawy ostrości poruszonego obrazu.
#
# **Uwaga : Niektóre komórki z kodem zawierają przykładowe wyniki poprawnie wykonanych elementów zadania. Nie usuwaj tych komórek i nie wykonuj ich ponownie, aby nie utracić przykładowych wyników.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Zadanie 1 - Wczytanie obrazu
#
# Wczytaj i wyświetl obrazy zad5_1.jpg i zad5_2.jpg. Obrazy przekonwertuj do skali szarości.
#
# Obraz zad5_1.jpg przedstawia nieporuszone zdjęcie obiektu, a obraz zad5_2.jpg zdjęcie tego samego obiektu poruszone w kierunku pionowym.

# %%
#Przykładowy efekt wczytania i wyświetlenia obrazu.

# %% [markdown]
# ## Zadanie 2 - Dekonwolucja
# Spróbuj opracować algorytm usuwający poruszenie z obrazu z pliku zad5_2.jpg. Przetworzony obraz porównaj z obrazem poruszonym i nieporuszonym.
#
# **Wskazówka 1. Zastosuje dekonwolucję usuwającą filtr uśredniający obraz przede wszystkim w kierunku pionowym.**
#
# **Wskazówka 2. Dekonwolucję spróbuj przeprowadzić za pomocą dwuwymiarowej dyskretnej transformacji Fouriera obrazu i filtru. Możesz ją obliczyć korzystając z funkcji fft2 z modułu numpy.fft**
#
# **Wskazów 3. Jeżeli chcesz podzielić przez siebie transformatę Fouriera obrazu i transformatę Fouriera filtru musisz je obliczyć dla tego samego zestawu częstotliwości. Najprościej zrobić to podając do funkcji fft2 obliczającej transformatę filtru argument s równy wymiarom transformaty obrazu.**
#
# **Wskazówka 4. Dzieląc przez siebie dwie transformaty Fouriera pamiętaj o regularyzacji.**

# %%
#Przykładowy efekt dekonwolucji
# Out:
# Text(0.5, 1.0, 'Obraz po dekonwolucji')
