# %% [markdown]
# <a href="https://colab.research.google.com/github/mackrasz/cyfrowe_przetwarzanie_obrazow/blob/master/Zadanie_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Korekcja barwy i zakresu dynamiki**

# %% [markdown]
# Twoim kolejnym zadaniem jest wykorzystanie korekcji barwy oraz generacji obrazów o szerokim zakresie dynamiki do poprawy jakości przykładowego obrazu.
#
# Obrazy potrzebne do wykonania ćwiczenia znajdziesz na GitHubie. Musisz jest skopiować na dysk w usłudze Google Colab lub na własny komputer - w zależności od tego jak wykonujesz ćwiczenie.
#
# **Uwaga : Niektóre komórki z kodem zawierają przykładowe wyniki poprawnie wykonanych elementów zadania. Nie usuwaj tych komórek i nie wykonuj ich ponownie, aby nie utracić przykładowych wyników.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.transform
from PIL import Image

# %% [markdown]
# ## Zadanie 1 - Generacja obrazów o szerokim zakresie dynamiki
#
# Wczytaj i wyświetl obrazy zad3_1.jpg oraz zad3_2.jpg. Ze względu na duży zakres dynamiki fotografowanej sceny (jasne niebo i ciemne obiekty wewnątrz pomieszczenia) nie da się bezpośrednio wyświetlić wszystkich szczegółów na jednym obrazie. Spróbuj połączyć dane z obu obrazów tak, aby uzyskać jeden obraz o wysokim zakresie dynamiki (HDR).
#
# **Wskazówka 1. Utwórz nowy obraz jako ważoną średnią obrazów wejściowych i zastosuj nieliniową korekcję kontrastu.**
#
# **Wskazówka 2. Lepszy efekt uzyskasz pracując na obrazach reprezentowanych przez liczby zmiennoprzecinkowe niż liczby całkowite.**

# %%
#Przykładowy efekt wczytania i wyświetlenia obrazów.

# %%
#Przykładowy efekt złożenia obrazów w obraz HDR

# %% [markdown]
# ## Zadanie 2 - Balans bieli
# Przykładowe obrazy zostały wykonane z ustawieniami kamery dostosowanymi do oświetlenia żarowego. W efekcie barwy na obrazie są zbyt niebieski. Skompensuj ten efekt na swoim obrazie HDR i wyświetl wynik na ekranie.

# %%
#Przykładowy efekt korekcji barwy
