# %% [markdown]
# <a href="https://colab.research.google.com/github/mackrasz/cyfrowe_przetwarzanie_obrazow/blob/master/Zadanie_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Filtry konwolucyjne**

# %% [markdown]
# To zadanie polega na wykorzystaniu filtrów konwolucyjnych do prostych operacji na obrazie.
#
# Obrazy potrzebne do wykonania ćwiczenia znajdziesz na GitHubie. Musisz jest skopiować na dysk w usłudze Google Colab lub na własny komputer - w zależności od tego jak wykonujesz ćwiczenie.
#
# **Uwaga : Niektóre komórki z kodem zawierają przykładowe wyniki poprawnie wykonanych elementów zadania. Nie usuwaj tych komórek i nie wykonuj ich ponownie, aby nie utracić przykładowych wyników.**

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal #Ten moduł jest użyteczny dla celów splotu
from PIL import Image

# %% [markdown]
# ## Zadanie 1 - Redukcja szumu
#
# Wczytaj i wyświetl obraz zad4_1.jpg. Przeprowadź filtrację obrazu filtrem o wybranej przez Ciebie masce tak, żeby zredukować poziom szumu w tym obrazie. Może to skutkować utratą ostrości obrazu. Obraz po filtracji powinien mieć ten sam rozmiar co obraz przed filtracją.
#
# **Wskazówka. Do filtracji możesz użyć funkcji convolve2d z moduły scipy.signal.**

# %%
#Przykładowy efekt wczytania i wyświetlenia obrazu.

# %%
#Przykładowy efekt filtracji obrazu

# %% [markdown]
# ## Zadanie 2 - Wyostrzanie
# Wczytaj obraz z pliku zad4_2.jpg i przeprowadź jego konwersję do skali szarości i filtrację filtrem o wybranej masce tak, aby wyostrzyć krawędzie w obrazie. Może to skutkować zwiększeniem widocznych szumów.

# %%
#Przykładowy efekt wczytania i wyświetlenia obrazu.

# %%
#Przykładowy efekt filtracji
